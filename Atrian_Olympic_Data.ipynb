# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df_olymp = pd.read_csv("D:\Belajar DA\Datasets-master\olympics.csv", skiprows = 1, skipfooter = 1)

# %%
df_olymp
# Out:
#                                        Unnamed: 0  № Summer  01 !  02 !  03 !  \
# 0                               Afghanistan (AFG)        13     0     0     2
# 1                                   Algeria (ALG)        12     5     2     8
# 2                                 Argentina (ARG)        23    18    24    28
# 3                                   Armenia (ARM)         5     1     2     9
# 4                         Australasia (ANZ) [ANZ]         2     3     4     5
# ..                                            ...       ...   ...   ...   ...
# 141                        Yugoslavia (YUG) [YUG]        16    26    29    28
# 142  Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# 143                            Zambia (ZAM) [ZAM]        12     0     1     1
# 144                          Zimbabwe (ZIM) [ZIM]        12     3     4     1
# 145                        Mixed team (ZZX) [ZZX]         3     8     5     4
#
# ...

# %%
df_olymp = df_olymp.rename(columns={'Unnamed: 0':'Country',
                                   '№ Summer':'#Summer Games',
                                   '01 !':'Gold',
                                   '02 !':'Silver',
                                   '03 !':'Bronze',
                                   'Total':'#Summer Medals',
                                   '№ Winter':'#Winter Games',
                                   '01 !.1':'Gold',
                                   '02 !.1':'Silver',
                                   '03 !.1':'Bronze',
                                   'Total.1':'#Winter Medals',
                                   '№ Games':'#Games',
                                   '01 !.2':'Gold',
                                   '02 !.2':'Silver',
                                   '03 !.2':'Bronze',})

# %%
df_olymp
# Out:
#                                           Country  #Summer Games  Gold  \
# 0                               Afghanistan (AFG)             13     0
# 1                                   Algeria (ALG)             12     5
# 2                                 Argentina (ARG)             23    18
# 3                                   Armenia (ARM)              5     1
# 4                         Australasia (ANZ) [ANZ]              2     3
# ..                                            ...            ...   ...
# 141                        Yugoslavia (YUG) [YUG]             16    26
# 142  Independent Olympic Participants (IOP) [IOP]              1     0
# 143                            Zambia (ZAM) [ZAM]             12     0
# 144                          Zimbabwe (ZIM) [ZIM]             12     3
# 145                        Mixed team (ZZX) [ZZX]              3     8
#
#      Silver  Bronze  #Summer Medals  #Winter Games  Gold  Silver  Bronze  \
# ...

# %%
list_country = df_olymp['Country'].str.split('(',expand=True)

# %%
list_country
# Out:
#                                      0           1
# 0                         Afghanistan         AFG)
# 1                             Algeria         ALG)
# 2                           Argentina         ARG)
# 3                             Armenia         ARM)
# 4                         Australasia   ANZ) [ANZ]
# ..                                 ...         ...
# 141                        Yugoslavia   YUG) [YUG]
# 142  Independent Olympic Participants   IOP) [IOP]
# 143                            Zambia   ZAM) [ZAM]
# 144                          Zimbabwe   ZIM) [ZIM]
# 145                        Mixed team   ZZX) [ZZX]
#
# [146 rows x 2 columns]

# %%
df_olymp['Country'] = list_country[0]

# %%
df_olymp
# Out:
#                                Country  #Summer Games  Gold  Silver  Bronze  \
# 0                         Afghanistan              13     0       0       2
# 1                             Algeria              12     5       2       8
# 2                           Argentina              23    18      24      28
# 3                             Armenia               5     1       2       9
# 4                         Australasia               2     3       4       5
# ..                                 ...            ...   ...     ...     ...
# 141                        Yugoslavia              16    26      29      28
# 142  Independent Olympic Participants               1     0       1       2
# 143                            Zambia              12     0       1       1
# 144                          Zimbabwe              12     3       4       1
# 145                        Mixed team               3     8       5       4
#
# ...

# %%
df_olymp.insert(1,'Code',list_country[1])

# %%
df_olymp
# Out:
#                                Country        Code  #Summer Games  Gold  \
# 0                         Afghanistan         AFG)             13     0
# 1                             Algeria         ALG)             12     5
# 2                           Argentina         ARG)             23    18
# 3                             Armenia         ARM)              5     1
# 4                         Australasia   ANZ) [ANZ]              2     3
# ..                                 ...         ...            ...   ...
# 141                        Yugoslavia   YUG) [YUG]             16    26
# 142  Independent Olympic Participants   IOP) [IOP]              1     0
# 143                            Zambia   ZAM) [ZAM]             12     0
# 144                          Zimbabwe   ZIM) [ZIM]             12     3
# 145                        Mixed team   ZZX) [ZZX]              3     8
#
#      Silver  Bronze  #Summer Medals  #Winter Games  Gold  Silver  Bronze  \
# ...

# %%
new_code = []
for i in range(len(df_olymp['Code'])):
    new_code.append(df_olymp['Code'][i][0:3])

# %%
new_code
# Out:
# ['AFG',
#  'ALG',
#  'ARG',
#  'ARM',
#  'ANZ',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BAH',
#  'BRN',
#  'BAR',
#  'BLR',
#  'BEL',
#  'BER',
#  'BOH',
#  'BOT',
#  'BRA',
#  'BWI',
#  'BUL',
#  'BDI',
#  'CMR',
#  'CAN',
#  'CHI',
#  'CHN',
#  'COL',
#  'CRC',
#  'CIV',
#  'CRO',
#  'CUB',
#  'CYP',
#  'CZE',
#  'TCH',
#  'DEN',
#  'DJI',
#  'DOM',
#  'ECU',
#  'EGY',
#  'ERI',
#  'EST',
#  'ETH',
#  'FIN',
#  'FRA',
#  'GAB',
#  'GEO',
#  'GER',
#  'EUA',
#  'GDR',
#  'FRG',
#  'GHA',
#  'GBR',
#  'GRE',
#  'GRN',
#  'GUA',
#  'GUY',
#  'HAI',
#  'HKG',
#  'HUN',
#  'ISL',
#  'IND',
#  'INA',
#  'IRI',
#  'IRQ',
#  'IRL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JPN',
#  'KAZ',
#  'KEN',
#  'PRK',
#  'KOR',
#  'KUW',
#  'KGZ',
#  'LAT',
#  'LIB',
#  'LIE',
#  'LTU',
#  'LUX',
#  'MKD',
#  'MAS',
#  'MRI',
#  'MEX',
#  'MDA',
#  'MGL',
#  'MNE',
#  'MAR',
#  'MOZ',
#  'NAM',
#  'NED',
#  'AHO',
#  'NZL',
#  'NIG',
#  'NGR',
#  'NOR',
#  'PAK',
#  'PAN',
#  'PAR',
#  'PER',
#  'PHI',
#  'POL',
# ...

# %%
df_olymp['Code'] = new_code

# %%
df_olymp
# Out:
#                                Country Code  #Summer Games  Gold  Silver  \
# 0                         Afghanistan   AFG             13     0       0
# 1                             Algeria   ALG             12     5       2
# 2                           Argentina   ARG             23    18      24
# 3                             Armenia   ARM              5     1       2
# 4                         Australasia   ANZ              2     3       4
# ..                                 ...  ...            ...   ...     ...
# 141                        Yugoslavia   YUG             16    26      29
# 142  Independent Olympic Participants   IOP              1     0       1
# 143                            Zambia   ZAM             12     0       1
# 144                          Zimbabwe   ZIM             12     3       4
# 145                        Mixed team   ZZX              3     8       5
#
#      Bronze  #Summer Medals  #Winter Games  Gold  Silver  Bronze  \
# ...

# %%
new_list = list(df_olymp.loc[2][-4:-1])
label_medal = list(df_olymp.columns[-4:-1])

# %%
import matplotlib.pyplot as plt
plt.pie(new_list, labels = label_medal)
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>

# %%
df_olymp = df_olymp.set_index('Country')
df_olymp
# Out:
#                                   Code  #Summer Games  Gold  Silver  Bronze  \
# Country
# Afghanistan                        AFG             13     0       0       2
# Algeria                            ALG             12     5       2       8
# Argentina                          ARG             23    18      24      28
# Armenia                            ARM              5     1       2       9
# Australasia                        ANZ              2     3       4       5
# ...                                ...            ...   ...     ...     ...
# Yugoslavia                         YUG             16    26      29      28
# Independent Olympic Participants   IOP              1     0       1       2
# Zambia                             ZAM             12     0       1       1
# Zimbabwe                           ZIM             12     3       4       1
# Mixed team                         ZZX              3     8       5       4
#
# ...
